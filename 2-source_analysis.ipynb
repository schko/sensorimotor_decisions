# %% [markdown]
# # Analyze sessions in batch from Phase 1 of AdaDrive (work in progress)

# %%
# %run 2-source.ipynb
all_source_powers = ['frontopolar_lh_4-8_Hz_Power', 'frontopolar_lh_8-15_Hz_Power', 'frontopolar_lh_15-32_Hz_Power', 'frontopolar_lh_32-55_Hz_Power', 'frontopolar_rh_4-8_Hz_Power', 'frontopolar_rh_8-15_Hz_Power', 'frontopolar_rh_15-32_Hz_Power', 'frontopolar_rh_32-55_Hz_Power', 'striate_lh_4-8_Hz_Power', 'striate_lh_8-15_Hz_Power', 'striate_lh_15-32_Hz_Power', 'striate_lh_32-55_Hz_Power', 'striate_rh_4-8_Hz_Power', 'striate_rh_8-15_Hz_Power', 'striate_rh_15-32_Hz_Power', 'striate_rh_32-55_Hz_Power', 'parastriate_lh_4-8_Hz_Power', 'parastriate_lh_8-15_Hz_Power', 'parastriate_lh_15-32_Hz_Power', 'parastriate_lh_32-55_Hz_Power', 'parastriate_rh_4-8_Hz_Power', 'parastriate_rh_8-15_Hz_Power', 'parastriate_rh_15-32_Hz_Power', 'parastriate_rh_32-55_Hz_Power', 'peristriate_lh_4-8_Hz_Power', 'peristriate_lh_8-15_Hz_Power', 'peristriate_lh_15-32_Hz_Power', 'peristriate_lh_32-55_Hz_Power', 'peristriate_rh_4-8_Hz_Power', 'peristriate_rh_8-15_Hz_Power', 'peristriate_rh_15-32_Hz_Power', 'peristriate_rh_32-55_Hz_Power', 'ventral_posterior_cingulate_lh_4-8_Hz_Power', 'ventral_posterior_cingulate_lh_8-15_Hz_Power', 'ventral_posterior_cingulate_lh_15-32_Hz_Power', 'ventral_posterior_cingulate_lh_32-55_Hz_Power', 'ventral_posterior_cingulate_rh_4-8_Hz_Power', 'ventral_posterior_cingulate_rh_8-15_Hz_Power', 'ventral_posterior_cingulate_rh_15-32_Hz_Power', 'ventral_posterior_cingulate_rh_32-55_Hz_Power', 'ventral_anterior_cingulate_lh_4-8_Hz_Power', 'ventral_anterior_cingulate_lh_8-15_Hz_Power', 'ventral_anterior_cingulate_lh_15-32_Hz_Power', 'ventral_anterior_cingulate_lh_32-55_Hz_Power', 'ventral_anterior_cingulate_rh_4-8_Hz_Power', 'ventral_anterior_cingulate_rh_8-15_Hz_Power', 'ventral_anterior_cingulate_rh_15-32_Hz_Power', 'ventral_anterior_cingulate_rh_32-55_Hz_Power', 'dorsal_posterior_cingulate_lh_4-8_Hz_Power', 'dorsal_posterior_cingulate_lh_8-15_Hz_Power', 'dorsal_posterior_cingulate_lh_15-32_Hz_Power', 'dorsal_posterior_cingulate_lh_32-55_Hz_Power', 'dorsal_posterior_cingulate_rh_4-8_Hz_Power', 'dorsal_posterior_cingulate_rh_8-15_Hz_Power', 'dorsal_posterior_cingulate_rh_15-32_Hz_Power', 'dorsal_posterior_cingulate_rh_32-55_Hz_Power', 'dorsal_anterior_cingulate_lh_4-8_Hz_Power', 'dorsal_anterior_cingulate_lh_8-15_Hz_Power', 'dorsal_anterior_cingulate_lh_15-32_Hz_Power', 'dorsal_anterior_cingulate_lh_32-55_Hz_Power', 'dorsal_anterior_cingulate_rh_4-8_Hz_Power', 'dorsal_anterior_cingulate_rh_8-15_Hz_Power', 'dorsal_anterior_cingulate_rh_15-32_Hz_Power', 'dorsal_anterior_cingulate_rh_32-55_Hz_Power', 'middle_frontal_lh_4-8_Hz_Power', 'middle_frontal_lh_8-15_Hz_Power', 'middle_frontal_lh_15-32_Hz_Power', 'middle_frontal_xlh_32-55_Hz_Power', 'middle_frontal_rh_4-8_Hz_Power', 'middle_frontal_rh_8-15_Hz_Power', 'middle_frontal_rh_15-32_Hz_Power', 'middle_frontal_rh_32-55_Hz_Power', 'premotor_lh_4-8_Hz_Power', 'premotor_lh_8-15_Hz_Power', 'premotor_lh_15-32_Hz_Power', 'premotor_lh_32-55_Hz_Power', 'premotor_rh_4-8_Hz_Power', 'premotor_rh_8-15_Hz_Power', 'premotor_rh_15-32_Hz_Power', 'premotor_rh_32-55_Hz_Power', 'superior_parietal_lh_4-8_Hz_Power', 'superior_parietal_lh_8-15_Hz_Power', 'superior_parietal_lh_15-32_Hz_Power', 'superior_parietal_lh_32-55_Hz_Power', 'superior_parietal_rh_4-8_Hz_Power', 'superior_parietal_rh_8-15_Hz_Power', 'superior_parietal_rh_15-32_Hz_Power', 'superior_parietal_rh_32-55_Hz_Power', 'intermediate_frontal_lh_4-8_Hz_Power', 'intermediate_frontal_lh_8-15_Hz_Power', 'intermediate_frontal_lh_15-32_Hz_Power', 'intermediate_frontal_lh_32-55_Hz_Power', 'intermediate_frontal_rh_4-8_Hz_Power', 'intermediate_frontal_rh_8-15_Hz_Power', 'intermediate_frontal_rh_15-32_Hz_Power', 'intermediate_frontal_rh_32-55_Hz_Power', 'dlpfc_lh_4-8_Hz_Power', 'dlpfc_lh_8-15_Hz_Power', 'dlpfc_lh_15-32_Hz_Power', 'dlpfc_lh_32-55_Hz_Power', 'dlpfc_rh_4-8_Hz_Power', 'dlpfc_rh_8-15_Hz_Power', 'dlpfc_rh_15-32_Hz_Power', 'dlpfc_rh_32-55_Hz_Power']

# %% [markdown]
# # Aggregate figures

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

motor_dfs_remap = motor_dfs.rename(columns={'ppid': 'sub'})
motor_dfs_remap['Abs_Steer_Wheel_Degree'] *= 100
sns.set_theme(style="ticks")
# Initialize a grid of plots with an Axes for each walk
grid = sns.FacetGrid(motor_dfs_remap, col="sub",
                     col_wrap=5, height=1.5, sharex=True)

# Draw a horizontal line for reference
grid.refline(y=3, linestyle=":")
# Draw a line plot to show the trajectory of each random walk
grid.map(sns.scatterplot, "Abs_Steer_Wheel_Degree", "Left Pupil Diameter", size=3, color="#4878CF")

# Adjust the tick positions and labels
#grid.set(xticks=np.arange(5), yticks=[-3, 3], xlim=(0, .9), ylim=(1.4, 7.3))
# overall ylabel
grid.set_axis_labels('', '') 
grid.fig.text(x=0, y=0.5, 
           verticalalignment='center', #make sure it's aligned at center vertically
           s='Left Pupil Diameter (mm)', #this is the text in the ylabel
           size=14, #customize the fontsize if you will
           rotation=90) #vertical text
grid.fig.text(x=0.5, y=0, 
           horizontalalignment='center', #make sure it's aligned at center
           s='Abs Steer Deviation (degrees)', #this is the text in the ylabel
           size=14, #customize the fontsize if you will
           rotation=0) # text
# Adjust the arrangement of the plots
grid.fig.tight_layout(w_pad=1)
grid.figure.savefig('steer vs pupil.png',dpi=300, bbox_inches='tight')

# %%
single_session_motors = motor_dfs.loc[(motor_dfs.ppid==13) & (motor_dfs.session==3)]
single_session_motors['trial_start_time'] = single_session_motors['trial_start_time']-single_session_motors.iloc[0]['trial_start_time']

# %%
import matplotlib.ticker as ticker
single_session_motors = motor_dfs.loc[(motor_dfs.ppid==13) & (motor_dfs.session==3)]
single_session_motors['trial_start_time'] = single_session_motors['trial_start_time']-single_session_motors.iloc[0]['trial_start_time']
x = single_session_motors['trial_start_time']
y = single_session_motors['Abs_Steer_Wheel_Degree']*100
pupils = single_session_motors['Left Pupil Diameter']
densities = single_session_motors['density']

f,(ax,ax2) = plt.subplots(1,2,sharey=True, facecolor='w')

# plot the same data on both axes
ax.scatter(x, y, marker='o', c=densities,sizes=pupils**4,linestyle='-',cmap=sns.color_palette("light:b", as_cmap=True),alpha=.8)
ax.plot(x, y, linestyle=':',color='grey',alpha=.3)

ax2.scatter(x, y, marker='o', c=densities,sizes=pupils**4,linestyle='-',cmap=sns.color_palette("light:b", as_cmap=True),alpha=.8)
ax2.plot(x, y, linestyle=':',color='grey',alpha=.3)

ax.set_xlim(-10,650)
ax2.set_xlim(750,1250)
ax.set_ylim(-2,60)
ax2.set_ylim(-2,60)
ax.set_xlabel('Steer action onset (sec)')
ax2.set_xlabel('Steer action onset (sec)')
ax.set_ylabel('Absolute Steering deviation (degrees)')

# hide the spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax.yaxis.tick_left()
#ax.tick_params(labelright='off')
ax2.yaxis.tick_right()

d = .015 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='r', clip_on=False)
ax.plot((1-d,1+d), (-d,+d), **kwargs)
ax.plot((1-d,1+d),(1-d,1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d,+d), (1-d,1+d), **kwargs)
ax2.plot((-d,+d), (-d,+d), **kwargs)

def fmt(x, pos):
    a, b = '{:.2e}'.format(x).split('e')
    b = int(b)
    return r'${} \times 10^{{{}}}$'.format(a, b)
mappable = plt.scatter(densities, densities, c=densities, cmap=sns.color_palette("light:b", as_cmap=True))
cbaxes = f.add_axes([.95, .4, 0.25, 0.02]) 

plt.colorbar(mappable,orientation='horizontal',label='trial opacity', cax = cbaxes)
legend_entries_num = 4
mappable = plt.scatter(pupils,pupils,s=pupils**4, alpha=.2).legend_elements("sizes", num=legend_entries_num)[0]
size_labels = list(np.round(np.linspace(np.min(pupils),np.max(pupils),legend_entries_num),0))
leg = plt.legend(title='    Left Pupil\nDiameter (mm)',handles = mappable, labels=size_labels,bbox_to_anchor=(.9,15), frameon=False)
plt.savefig('single_session.png',dpi=300, bbox_inches='tight')

# %%
motor_dfs_renamed = motor_dfs.rename(columns={'Abs_Steer_Wheel_Degree': "Absolute steering deviation (degrees)", 'ppid':'sub'})
motor_dfs_renamed["Absolute steering deviation (degrees)"] *= 100
sns.histplot(data=motor_dfs_renamed, x="Absolute steering deviation (degrees)", kde=True,hue='sub',palette = 'muted')
plt.box(False)
plt.savefig('motor_all_degs.png',dpi=600,bbox_inches='tight')

# %%
summary = pd.DataFrame(mdf.summary().tables[1].iloc[:-1])
summary['P>|z|'] = summary['P>|z|'].astype(float)
summary = summary.astype(float)
roi_col_name = 'ROI Power ($\mu V^2$)'
summary = summary[summary['P>|z|']<=0.05][['Coef.','Std.Err.','P>|z|']].reset_index().rename(columns={'index':roi_col_name,'P>|z|': 'p-val'})
positions = {}
for l in rel_labels:
    positions[rel_mappings[l.name]] = l.pos.mean(axis=0)
xyz_positions = []
for r in summary[roi_col_name]:
    xyz_positions.append(positions[r.rsplit('_',4)[0]]/0.001)
xyz_positions = pd.DataFrame(list(map(np.ravel, xyz_positions)))
xyz_positions.columns = ['x','y','z']
xyz_positions.columns = [('MNE Coordinate (mm)', c) for c in xyz_positions.columns]

summary[roi_col_name] = summary[roi_col_name].replace(rename_dict, regex=True)
summary.columns = [('Independant variable', c) for c in summary.columns]
summary.columns = pd.MultiIndex.from_tuples([(c[0], c[1]) for c in summary.columns])
summary = pd.concat([summary,xyz_positions],axis=1)
summary[('Independant variable',roi_col_name)] = summary[('Independant variable',roi_col_name)].str.replace('μ','\mu ')

display(summary)
print(summary.to_latex(index=False, float_format=lambda x: '%.3f' % x,multicolumn_format='c',escape=False))

# %% [markdown]
# # Correlation analysis

# %%
from scipy.stats import spearmanr
motor_dfs_corr = motor_epochs_metadata[['Left Pupil Diameter','NSLR_mean_duration_Saccade','NSLR_count_Saccade','Abs_Steer_Wheel_Degree','density',
                            'bpm','rmssd','pnn50','trial_damage','ppid']+significant_regions].dropna()
motor_dfs_corr['NSLR_mean_duration_Saccade'] *= 1000
motor_dfs_corr['Abs_Steer_Wheel_Degree'] *= 100
rho = motor_dfs_corr.corr(method='spearman')
pval = motor_dfs_corr.corr(method=lambda x, y: spearmanr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [.05, .01, .001] if x<=t]))
rho_df = rho.round(2).astype(str) + p
rho_df = rho_df.reset_index().rename(columns=rename_dict)
rho_df['measure'] = rho_df.measure.replace(rename_dict, regex=True)
rho_df.columns = ['measure'] + list(rho_df['measure'])
display(rho_df)
print(rho_df.to_latex(index=False,float_format="{:0.2f}".format))

# %%
from scipy.stats import spearmanr
import matplotlib.pyplot as plt 
sns.set_style("white")
hues_found = True
rename_dict = OrderedDict({'index':'measure','Abs_Steer_Wheel_Degree':'Motor intensity (deg)', 'density': 'Trial opacity',
               'NSLR_count_Saccade': 'Saccade count',
               'NSLR_mean_duration_Saccade': 'Saccade duration (ms)',
               '_rh_4-8_Hz_Power': ' Theta RH',
              '_rh_8-15_Hz_Power': ' Alpha RH',
               '_rh_15-32_Hz_Power': ' Beta RH',
               '_rh_32-55_Hz_Power': ' Gamma RH',
               '_lh_4-8_Hz_Power': ' Theta LH',
              '_lh_8-15_Hz_Power': ' Alpha LH',
               '_lh_15-32_Hz_Power': ' Beta LH',
               '_lh_32-55_Hz_Power': ' Gamma LH',
               'dorsal_anterior_cingulate': 'dACC',
               'ventral_anterior_cingulate': 'vACC',
               'dlpfc': 'DLPFC',
               'parastriate': 'V2',
                'striate': 'V1',
                'intermediate_frontal': 'MFG',
               '_': ' ',
               'ppid': 'Participant ID',
              'bpm':'BPM', 'rmssd':'RMSSD (ms)','pnn50':'PNN50','Left Pupil Diameter':'Pupil Diameter (mm)'
              })
def corrfunc(x, y, hue=None, ax=None, **kws):
    """Plot the correlation coefficient in the top left hand corner of a plot."""
    tmp = pd.DataFrame([x,y]).T
    tmp = tmp[tmp.notnull().all(axis=1)]
    r, p = spearmanr(tmp.iloc[:,0], tmp.iloc[:,1])
    p = ''.join(['*' for t in [.05, .01, .001] if p<=t])
    ax = ax or plt.gca()
    ax.clear()
    sns.regplot(x=x,y=y,ax=ax,scatter_kws={"color": "grey"}, line_kws={"color": "red"})
    ax.annotate(f'ρ = {r:.2f}{p}', xy=(.1, .9), xycoords=ax.transAxes,bbox=dict(boxstyle="round", fc="0.8"))

def upper_plots(x, y, label=None, ax=None, **kws):
    print('here',hues_found)
    print(label)
    ax = ax or plt.gca()
    sns.scatterplot(x=x,y=y,hue=True,ax=ax)

outlier_motor_dfs_corr = motor_dfs_corr[['ventral_anterior_cingulate_lh_15-32_Hz_Power',
'dorsal_anterior_cingulate_lh_4-8_Hz_Power', 'dlpfc_lh_15-32_Hz_Power',
'Left Pupil Diameter','NSLR_mean_duration_Saccade','rmssd','ppid']].rename(columns=rename_dict)
outlier_motor_dfs_corr.columns = pd.Series(outlier_motor_dfs_corr.columns).replace(rename_dict, regex=True)
for col in list(outlier_motor_dfs_corr.columns):
    try:
        pd_series = outlier_motor_dfs_corr[col].copy()
        outlier_motor_dfs_corr[col] = pd_series[pd_series.between(pd_series.quantile(.05), pd_series.quantile(.95))]
    except:
        pass

g = sns.pairplot(outlier_motor_dfs_corr,kind='kde',diag_kind='kde',aspect=1, height=3,hue='Participant ID',palette='muted',plot_kws=dict(marker="+", linewidth=1,alpha=.6,fill=True))
g.map_lower(corrfunc,hue=None)
plt.savefig('corrplot.png',dpi=300)
plt.show()
